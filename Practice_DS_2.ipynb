# %% [markdown]
# <a href="https://colab.research.google.com/github/AdnanAnwarR/practice_DS/blob/main/Practice_DS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operator

# %% [markdown]
# ## Aritmetik

# %%
a = 7
b = 3

# %%
a + b
# Out:
# 10

# %%
a - b
# Out:
# 4

# %%
# Kalau tidak pakai print, perintah terakhir saja yang muncul pada output
a + b
a - b
# Out:
# 4

# %%
print(a + b)
print(a - b)
# Out:
# 10
# 4

# %%
a * b
# Out:
# 21

# %%
a / b
# Out:
# 2.3333333333333335

# %%
# Operator / (bagi) selalu menghasilkan bilangan float,
# meskipun secara matematis hasil baginya bilangan bulat.
9 / 3
# Out:
# 3.0

# %%
9 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_905/761053603.py in <cell line: 0>()
# ----> 1 9 / 0
#
# ZeroDivisionError: division by zero

# %%
a // b
# Out:
# 2

# %%
a ** b
# Out:
# 343

# %%
a % b
# Out:
# 1

# %%
# Bagaimana cara mengecek apakah suatu bilangan itu genap/ganjil?
a = 7
if a%2 == 0:
    print(f'{a} adalah bilangan genap')
else:
    print(f'{a} adalah bilangan ganjil')
# Out:
# 7 adalah bilangan ganjil

# %%
import math

math.floor(7/3)
# Out:
# 2

# %%
math.ceil(7/3)
# Out:
# 3

# %% [markdown]
# ## Penugasan

# %%
mynumber = 37
mynumber
# Out:
# 37

# %%
mynumber += 5
mynumber
# Out:
# 42

# %%
myanothernumber += 8
myanothernumber
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_905/1894337096.py in <cell line: 0>()
# ----> 1 myanothernumber += 8
#       2 myanothernumber
#
# NameError: name 'myanothernumber' is not defined

# %%
mystring = "Jeruk warnanya orange"
mystring
# Out:
# 'Jeruk warnanya orange'

# %%
mystring += "suffix"
mystring
# Out:
# 'Jeruk warnanya orangesuffix'

# %%
mystring = "Prefix" + mystring
mystring
# Out:
# 'PrefixJeruk warnanya orangesuffix'

# %%
mystring -= "suffix"
mystring
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_905/3724052857.py in <cell line: 0>()
# ----> 1 mystring -= "suffix"
#       2 mystring
#
# TypeError: unsupported operand type(s) for -=: 'str' and 'str'

# %% [markdown]
# ## Perbandingan

# %%
a = 7
b = 3
c = 9

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b > c
# Out:
# False

# %%
# True    False
a > b and b > c
# Out:
# False

# %%
a > b < c
# Out:
# True

# %%
# True    True
a > b and b < c
# Out:
# True

# %% [markdown]
# ## Logika

# %%
# False   True     True
a < b and b < c or a < c
# Out:
# True

# %%
# False    True     True
a < b and (b < c or a < c)
# Out:
# False

# %%
# Kalau and duluan, langkahnya seperti ini
# True or False
# True

# Kalau or duluan, langkahnya seperti ini
# True and False
# False

True or False and False
# Out:
# True

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
f"Pi sampai 20 digit = {math.pi:.20f}"
# Out:
# 'Pi sampai 20 digit = 3.14159265358979311600'

# %% [markdown]
# ## Keanggotaan

# %%
warna = ["merah", "jingga", "kuning", "hijau", "biru", "ungu"]

# %%
"merah" in warna
# Out:
# True

# %%
"navy" in warna
# Out:
# False

# %%
request_warna = "teal"
if request_warna in warna:
    print("Warna tersedia.")
else:
    print("Warna belum tersedia.")
# Out:
# Warna belum tersedia.

# %% [markdown]
# # Tipe Data

# %% [markdown]
# ## String

# %%
mytext = "Air mineral murni sejuk"

# %%
mytext *= "biru"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_905/1668795436.py in <cell line: 0>()
# ----> 1 mytext *= "biru"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
mytext *= 3
mytext
# Out:
# 'Air mineral murni sejukAir mineral murni sejukAir mineral murni sejuk'

# %%
mytext /= 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_905/852767872.py in <cell line: 0>()
# ----> 1 mytext /= 3
#
# TypeError: unsupported operand type(s) for /=: 'str' and 'int'

# %%
# Apakah ada kata "Air" di dalam mytext
"Air" in mytext
# Out:
# True

# %%
"air" in mytext
# Out:
# False

# %%
# Potong mytext berdasarkan spasi
mytext.split()
# Out:
# ['Air',
#  'mineral',
#  'murni',
#  'sejukAir',
#  'mineral',
#  'murni',
#  'sejukAir',
#  'mineral',
#  'murni',
#  'sejuk']

# %%
# Potong mytext berdasarkan huruf "A"
mytext.split("A")
# Out:
# ['',
#  'ir mineral murni sejuk',
#  'ir mineral murni sejuk',
#  'ir mineral murni sejuk']

# %%
mytext.upper()
# Out:
# 'AIR MINERAL MURNI SEJUKAIR MINERAL MURNI SEJUKAIR MINERAL MURNI SEJUK'

# %%
mytext.lower()
# Out:
# 'air mineral murni sejukair mineral murni sejukair mineral murni sejuk'

# %%
mytext.replace("sejukAir", "sejuk Air")
# Out:
# 'Air mineral murni sejuk Air mineral murni sejuk Air mineral murni sejuk'

# %%
# Cara menambahkan enter di dalam string,
# yakni dengan \n
print(mytext.replace("sejukAir", "sejuk\nAir"))
# Out:
# Air mineral murni sejuk
# Air mineral murni sejuk
# Air mineral murni sejuk

# %% [markdown]
# # Struktur Data

# %% [markdown]
# ## Basic dari Python

# %% [markdown]
# ### List

# %%
mylist = [1, 2, 3, 4, 5, 6]
mylist
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# List di dalam list
mylist = [
    [0, 0],
    [0, 1],
    [1, 1],
]
mylist
# Out:
# [[0, 0], [0, 1], [1, 1]]

# %%
mylist = [
    "Apel",
    9,
    [3, 7],
]
mylist
# Out:
# ['Apel', 9, [3, 7]]

# %%
myfirstlist = [1, 2, 3]
mysecondlist = [6, 7, 8]
myfirstlist + mysecondlist
# Out:
# [1, 2, 3, 6, 7, 8]

# %%
myfirstlist + [4]
# Out:
# [1, 2, 3, 4]

# %%
myfirstlist.append(4)
myfirstlist
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### Tuple

# %%
mytuple = (1, 2, 3)
mytuple
# Out:
# (1, 2, 3)

# %%
mytuple + (4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_905/3593889309.py in <cell line: 0>()
# ----> 1 mytuple + (4)
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
mytuple[0]
# Out:
# 1

# %%
mytuple[0] = 4
mytuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_905/1087545528.py in <cell line: 0>()
# ----> 1 mytuple[0] = 4
#       2 mytuple
#
# TypeError: 'tuple' object does not support item assignment

# %%
mysecondtuple = (6, 7, 8)
mynewtuple = mytuple + mysecondtuple
mynewtuple
# Out:
# (1, 2, 3, 6, 7, 8)

# %% [markdown]
# ### Range

# %%
range(4)
# Out:
# range(0, 4)

# %%
list(range(4))
# Out:
# [0, 1, 2, 3]

# %%
list(range(7, 36, 6))
# Out:
# [7, 13, 19, 25, 31]

# %% [markdown]
# ### Dict

# %%
mydictionary = {
    "customer": "Anna",
    "tanggal_login": "2026-04-11",
    "produk": "Tumbler",
    "Banyak": 3,
    "Harga": 100000,
}

# %%
mydictionary
# Out:
# {'customer': 'Anna',
#  'tanggal_login': '2026-04-11',
#  'produk': 'Tumbler',
#  'Banyak': 3,
#  'Harga': 100000}

# %%
mydictionary["customer"]
# Out:
# 'Anna'

# %%
"promo" in mydictionary
# Out:
# False

# %%
mydictionary["promo"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_905/401441743.py in <cell line: 0>()
# ----> 1 mydictionary["promo"]
#
# KeyError: 'promo'

# %%
mydictionary.get("promo")

# %%
mydictionary.get("promo", "Tidak ada promo")
# Out:
# 'Tidak ada promo'

# %%
mysecondictionary = {
    "nama": "Anna",
    "nama": "Sentosa",
}
mysecondictionary
# Out:
# {'nama': 'Sentosa'}

# %%
mysecondictionary["nama"]
# Out:
# 'Sentosa'

# %% [markdown]
# ### Set

# %%
myset = {2, 3, 4, 5}
myset
# Out:
# {2, 3, 4, 5}

# %%
myset = {2, 3, 4, 5, 5}
myset
# Out:
# {2, 3, 4, 5}

# %%
myset = {5, 2, 3, 4, 5, 5}
myset
# Out:
# {2, 3, 4, 5}

# %%
mylist = ["Aceh", "Jawa Barat", "Bali", "Jawa Barat"]
set(mylist)
# Out:
# {'Aceh', 'Bali', 'Jawa Barat'}

# %% [markdown]
# ## Pakai NumPy

# %%
import numpy as np

# %%
mylist = [1, 2, 3]
myarray = np.array([1, 2, 3])

# %%
mylist
# Out:
# [1, 2, 3]

# %%
myarray
# Out:
# array([1, 2, 3])

# %%
mysecondlist = [6, 7, 8]
mysecondarray = np.array([6, 7, 8])

# %%
mylist + mysecondlist
# Out:
# [1, 2, 3, 6, 7, 8]

# %%
myarray + mysecondarray
# Out:
# array([ 7,  9, 11])

# %%
myarray * mysecondarray
# Out:
# array([ 6, 14, 24])

# %%
np.dot(myarray, mysecondarray)
# Out:
# np.int64(44)

# %% [markdown]
# # Challenge

# %%
# Bagaimana cara kita mengurutkan 2 buah string seperti di dalam kamus.
# Kita tidak tahu mana yang isinya "Gelas", mana yang isinya "Kartu".
# Misalnya, input berikut:
teks1 = "Kartu"
teks2 = "Gelas"

# Ekspektasinya terurut alfabet:
# Gelas
# Kartu

# %%
if teks1 < teks2:
  print(teks1)
  print(teks2)
else:
  print(teks2)
  print(teks1)
# Out:
# Gelas
# Kartu

# %%
teks1 = "Kartu"
teks2 = "Gelas"
newString = [teks1, teks2]
newString.sort()
newString
# Out:
# ['Gelas', 'Kartu']
