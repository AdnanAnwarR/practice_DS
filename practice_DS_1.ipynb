# %% [markdown]
# <a href="https://colab.research.google.com/github/AdnanAnwarR/practice_DS/blob/main/practice_DS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Variable

# %% [markdown]
# ## variable angka

# %%
x = 10
salam = "Good morning"

# %% [markdown]
# ## variable huruf

# %%
print(x)
print(salam)
salam
# Out:
# 10
# Good morning
# 'Good morning'

# %% [markdown]
# #if and else

# %%
lampu = "nyala"

if(lampu == "nyala"):
  print("lampu nyala")
else:
  print("lampu mati")
# Out:
# lampu nyala

# %% [markdown]
# #if, elif, and else

# %%
if(lampu == "nyala"):
  print("lampu nyala")
elif(lampu == "hijau"):
  print("lampu hijau")
else:
  print("lampu mati")
# Out:
# lampu hijau

# %%
lampu = "hijau"

# %% [markdown]
# #import

# %%
import pandas

# %%
pandas.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # input

# %%
name = input()
# Out:
# jono

# %%
print(name)
# Out:
# jono

# %%
umur = input("masukkan umur :")
umur = int(umur)
# Out:
# masukkan umur :30

# %%
print(umur)
# Out:
# 30

# %%
umur = umur + 10
print(umur)
# Out:
# 40
