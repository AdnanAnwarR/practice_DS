# %% [markdown]
# <a href="https://colab.research.google.com/github/AdnanAnwarR/practice_DS/blob/main/Hands_On_Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Langkah  1 — Perhitungan Dasar

# %% [markdown]
#  Peserta akan berlatih menggunakan Python untuk operasi dasar:
# * Penjumlahan
# * Pengurangan
# * Perkalian
# * Pembagian
# * Pangkat
# * Modulus

# %%
#inisialisasi
a = 8
b = 7
c=3

# %%
#penjumlahan
a + b
# Out:
# 15

# %%
#pengurangan
a-b
# Out:
# 1

# %%
#perkalian
a * b
# Out:
# 56

# %%
#pembagian
a / b
# Out:
# 1.1428571428571428

# %%
#pangkat
c**c
# Out:
# 27

# %%
#modulus
a % b
# Out:
# 1

# %% [markdown]
# # Langkah  2 — Mengenal Data Types di Python

# %% [markdown]
# 1. Character (String)

# %%
mystring = "Jeruk warnanya orange"
mystring
# Out:
# 'Jeruk warnanya orange'

# %%
mystring += "banget"
mystring
# Out:
# 'Jeruk warnanya orangebanget'

# %% [markdown]
# 2. Numeric – Integer

# %%
angka = 10
print(angka)
print(type(angka))
# Out:
# 10
# <class 'int'>

# %% [markdown]
# 3. Numeric – Real/Decimal (Float)

# %%
floats = 49.82
print(floats)
print(type(floats))
# Out:
# 49.82
# <class 'float'>

# %% [markdown]
# 4. Logical (Boolean)

# %%
benar = True
salah = False
print(benar)
print(type(benar))
print(salah)
print(type(salah))
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %% [markdown]
# 5. Complex Number

# %%
z = 3 + 4j
print(type(z))
# Out:
# <class 'complex'>

# %% [markdown]
# # Langkah  3 — Mengenal Struktur Data Python

# %% [markdown]
# 1. Vector

# %%
#list
mylist = [1, 2, 3, 4, 5, 6]
mylist
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#numpy
import numpy as np
myarray = np.array([1, 2, 3,7])
print(myarray)
# Out:
# [1 2 3 7]

# %% [markdown]
# 2. List

# %%
list_makanan = ["ayam","ikan","burger","ikan"]
list_makanan
# Out:
# ['ayam', 'ikan', 'burger', 'ikan']

# %% [markdown]
# 3. Matrix

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]
print(matrix)
print(matrix[2])
print(matrix[2][1])
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# [7, 8, 9]
# 8

# %% [markdown]
# 4. Set

# %%
print(list_makanan)
set_makanan = set(list_makanan)
print(set_makanan)
# Out:
# ['ayam', 'ikan', 'burger', 'ikan']
# {'ikan', 'ayam', 'burger'}

# %% [markdown]
# 5. Tuple

# %%
titik_a = (3, 4)
titik_b = (-2, 5)
titik_c = (0, 0)

print(titik_a)
print(titik_b)
print(titik_c)
# Out:
# (3, 4)
# (-2, 5)
# (0, 0)

# %% [markdown]
# 6. Dictionary

# %%
mahasiswa = {
    "M001": {
        "nama": "Budi Santoso",
        "umur": 20,
        "nilai": 85.5
    },
    "M002": {
        "nama": "Ani Wijaya",
        "umur": 19,
        "nilai": 92.0
    }
}

print(mahasiswa)
# Out:
# {'M001': {'nama': 'Budi Santoso', 'umur': 20, 'nilai': 85.5}, 'M002': {'nama': 'Ani Wijaya', 'umur': 19, 'nilai': 92.0}}

# %% [markdown]
# 7. Array

# %%
import numpy as pd
Myarray = np.array([1, 2, 3, 4])
MyList = [9,8,7,6]

# %%
print(myarray)
print(Myarray)
array_total = myarray + Myarray
print(array_total)
# Out:
# [1 2 3 7]
# [1 2 3 4]
# [ 2  4  6 11]

# %%
# Matriks 2x3
A = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

# Matriks 3x2
B = np.array([
    [7, 8],
    [9, 10],
    [11, 12]
])

# %%
C = np.dot(A, B)
print(C)
# Out:
# [[ 58  64]
#  [139 154]]
