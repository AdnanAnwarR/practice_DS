# %% [markdown]
# <a href="https://colab.research.google.com/github/AdnanAnwarR/practice_DS/blob/main/Tugas_3_Adnan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Soal 1: Set Up Jupyter/Colab
# * Adnan Anwar Rabbani
# * 11 April 2026
# * Tugas 3 Kategori Penjualan

# %% [markdown]
# # Soal 2: Membuat input
# Buatlah dua kode agar pengguna bisa melakukan input untuk data berikut:
# * Nama produk
# * Jumlah produk terjual
# * Harga produk

# %%
#input nama produk
nama_produk = input("Masukkan Nama Produk : ")

#input jumlah produk terjual
jml_produk = int(input("Jumlah Produk Terjual : "))

#input harga produk
harga_produk = int(input("Harga Produk : "))
# Out:
# Masukkan Nama Produk : baju
# Jumlah Produk Terjual : 100
# Harga Produk : 70000

# %% [markdown]
# # Soal 3: Logika If/Else untuk Rekomendasi Produk
# ## Lakukan perhitungan total revenue dari penjualan barang dengan rumus:
# **total revenue = jumlah_produk_terjual  x harga_produk.**
# ## Gunakan conditional statement untuk melihat hasil akhir penilaian:
# * Jika total revenue kurang dari atau sama dengan 2.000.000, maka kategori penjualan “Rendah”.
# * Jika total revenue lebih dari 2.000.000 dan total revenue kurang dari atau sama dengan  8.000.000, maka kategori penjualan “Sedang”.
# * Jika total revenue lebih dari 8.000.000, maka kategori penjualan “Tinggi”.

# %%
total_revenue = jml_produk * harga_produk

#jika total revenue kurang dari 2.000.000
if total_revenue <= 2000000:
  kategori = "kategori penjualan rendah"

#jika total revenue lebih dari 2.000.000 dan kurang dari sama dengan 8.000.000
elif total_revenue > 2000000 and total_revenue <= 8000000:
  kategori = "kategori penjualan sedang"

#jika total revenue lebih dari 8.000.000
else:
  kategori = "kategori penjualan tinggi"

# %% [markdown]
# # Soal 4: Output Akhir Program
# ## Tampilkan rekomendasi hasil analisis penjualan yang meliputi:
# * Nama Produk
# * Jumlah Terjual
# * Harga Produk
# * Total Revenue
# * Kategori Penjualan (Rendah, sedang, tinggi)

# %%
#menampilkan rekomendasi hasil analisis penjualan
print("nama produk   : " , nama_produk)
print("jumlah produk : " , jml_produk)
print("harga produk  : " , harga_produk)
print("total revenue : " , total_revenue)
print("rekomendasi produk : " , kategori)
# Out:
# nama produk   :  baju
# jumlah produk :  100
# harga produk  :  70000
# total revenue :  7000000
# rekomendasi produk :  kategori penjualan sedang

# %% [markdown]
# # 5.Penjelasan Logika Program

# %%
# Bagaimana total revenue dihitung?
# jawab : total revenue dihitung dari jumlah produk dikali harga produk

# Bagaimana if/else digunakan menentukan kategori penjualan?
# jawab : disini jika total revenuenya kurang dari sama dengan 2.000.000 maka kategori penjualan rendah
#         dan jika total_revenuenya lebih dari 2.000.000 dan kurang dari sama dengan 8.000.000 maka kategori penjualan sedang
#         dan jika total_revenuenya lebih dari 8.000.000 maka kategori penjualannya tinggi

# %% [markdown]
# # Reflection Question
# Setelah menyelesaikan studi kasus di atas, buatlah sebuah text cell atau kdoe dalam bentuk komentar  di paling bawah file program anda, lalu jawablah pertanyaan berikut:
# * Menurut Anda, mengapa  kemampuan dasar seperti input, perhitungan, dan if/else perlu dikuasai lebih dulu?
# * Bagaimana pemahaman dasar ini membantu Anda untuk mempelajari materi Python tingkat berikutnya?
#
# # Jawab
# * Kemampuan dasar (input, perhitungan, if/else) perlu dikuasai lebih dulu karena merupakan fondasi logika pemrograman. Tanpa itu, mustahil memahami alur program, pengambilan keputusan, atau interaksi dengan pengguna.
#
# * Pemahaman dasar ini membantu untuk belajar materi Python tingkat berikutnya (seperti looping, function, list, dictionary, atau OOP)
