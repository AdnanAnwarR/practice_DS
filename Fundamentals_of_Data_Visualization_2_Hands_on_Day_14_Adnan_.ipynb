# %% [markdown]
# <a href="https://colab.research.google.com/github/AdnanAnwarR/practice_DS/blob/main/Fundamentals_of_Data_Visualization_2_Hands_on_Day_14_Adnan_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Library

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
# import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print('numpy version : ',np.__version__)
print('pandas version : ',pd.__version__)
print('seaborn version : ',sns.__version__)
# print('matplotlib version : ',matplotlib.__version__)
# Out:
# numpy version :  2.0.2
# pandas version :  2.2.2
# seaborn version :  0.13.2

# %% [markdown]
# ## Tidy data format

# %%
# define the data
data = pd.DataFrame({
    'group':['control','variant'],
    'click':[231,265],
    'not-click':[1032,1019]
})

# show the data
data
# Out:
#      group  click  not-click
# 0  control    231       1032
# 1  variant    265       1019

# %%
data_tidy = pd.melt(data,
                    id_vars='group',
                    var_name='response')

data_tidy
# Out:
#      group   response  value
# 0  control      click    231
# 1  variant      click    265
# 2  control  not-click   1032
# 3  variant  not-click   1019

# %% [markdown]
# ## Visualizing bivariate data

# %%
tips_df = sns.load_dataset('tips')
tips_df['score'] = np.log(tips_df['total_bill']+1)
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size     score
# 0       16.99  1.01  Female     No  Sun  Dinner     2  2.889816
# 1       10.34  1.66    Male     No  Sun  Dinner     3  2.428336
# 2       21.01  3.50    Male     No  Sun  Dinner     3  3.091497
# 3       23.68  3.31    Male     No  Sun  Dinner     2  3.205993
# 4       24.59  3.61  Female     No  Sun  Dinner     4  3.242202

# %% [markdown]
# ### scatterplot

# %%
fig, ax = plt.subplots(figsize=(15,10))

sns.scatterplot(
    x="total_bill", y="tip",
    data=tips_df,
    s=200
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
fig, ax = plt.subplots(figsize=(15,10))

plt.scatter(x="total_bill", y="tip",
            data=tips_df,
            s=200)

# %% [markdown]
# ### Line Plot

# %%
df = pd.DataFrame({'date': ['1/2/2021',
                            '1/3/2021',
                            '1/4/2021',
                            '1/5/2021',
                            '1/6/2021',
                            '1/7/2021',
                            '1/8/2021'],
                   'value': [4, 7, 8, 13, 17, 15, 21]})

df
# Out:
#        date  value
# 0  1/2/2021      4
# 1  1/3/2021      7
# 2  1/4/2021      8
# 3  1/5/2021     13
# 4  1/6/2021     17
# 5  1/7/2021     15
# 6  1/8/2021     21

# %%
fig, ax = plt.subplots(figsize=(15,10))

sns.lineplot(x="date", y="value",
             data=df,marker= 'o')
# Out:
# <Axes: xlabel='date', ylabel='value'>

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.plot(df.date,
         df.value)
plt.show()

# %%
# df = pd.read_csv('sample_data/flights.csv')
# df.head()

# %%
data = [{'year': 1949, 'month': 'Jan', 'passengers': 112},
 {'year': 1949, 'month': 'Feb', 'passengers': 118},
 {'year': 1949, 'month': 'Mar', 'passengers': 132},
 {'year': 1949, 'month': 'Apr', 'passengers': 129},
 {'year': 1949, 'month': 'May', 'passengers': 121},
 {'year': 1949, 'month': 'Jun', 'passengers': 135},
 {'year': 1949, 'month': 'Jul', 'passengers': 148},
 {'year': 1949, 'month': 'Aug', 'passengers': 148},
 {'year': 1949, 'month': 'Sep', 'passengers': 136},
 {'year': 1949, 'month': 'Oct', 'passengers': 119},
 {'year': 1949, 'month': 'Nov', 'passengers': 104},
 {'year': 1949, 'month': 'Dec', 'passengers': 118},
 {'year': 1950, 'month': 'Jan', 'passengers': 115},
 {'year': 1950, 'month': 'Feb', 'passengers': 126},
 {'year': 1950, 'month': 'Mar', 'passengers': 141},
 {'year': 1950, 'month': 'Apr', 'passengers': 135},
 {'year': 1950, 'month': 'May', 'passengers': 125},
 {'year': 1950, 'month': 'Jun', 'passengers': 149},
 {'year': 1950, 'month': 'Jul', 'passengers': 170},
 {'year': 1950, 'month': 'Aug', 'passengers': 170},
 {'year': 1950, 'month': 'Sep', 'passengers': 158},
 {'year': 1950, 'month': 'Oct', 'passengers': 133},
 {'year': 1950, 'month': 'Nov', 'passengers': 114},
 {'year': 1950, 'month': 'Dec', 'passengers': 140},
 {'year': 1951, 'month': 'Jan', 'passengers': 145},
 {'year': 1951, 'month': 'Feb', 'passengers': 150},
 {'year': 1951, 'month': 'Mar', 'passengers': 178},
 {'year': 1951, 'month': 'Apr', 'passengers': 163},
 {'year': 1951, 'month': 'May', 'passengers': 172},
 {'year': 1951, 'month': 'Jun', 'passengers': 178},
 {'year': 1951, 'month': 'Jul', 'passengers': 199},
 {'year': 1951, 'month': 'Aug', 'passengers': 199},
 {'year': 1951, 'month': 'Sep', 'passengers': 184},
 {'year': 1951, 'month': 'Oct', 'passengers': 162},
 {'year': 1951, 'month': 'Nov', 'passengers': 146},
 {'year': 1951, 'month': 'Dec', 'passengers': 166},
 {'year': 1952, 'month': 'Jan', 'passengers': 171},
 {'year': 1952, 'month': 'Feb', 'passengers': 180},
 {'year': 1952, 'month': 'Mar', 'passengers': 193},
 {'year': 1952, 'month': 'Apr', 'passengers': 181},
 {'year': 1952, 'month': 'May', 'passengers': 183},
 {'year': 1952, 'month': 'Jun', 'passengers': 218},
 {'year': 1952, 'month': 'Jul', 'passengers': 230},
 {'year': 1952, 'month': 'Aug', 'passengers': 242},
 {'year': 1952, 'month': 'Sep', 'passengers': 209},
 {'year': 1952, 'month': 'Oct', 'passengers': 191},
 {'year': 1952, 'month': 'Nov', 'passengers': 172},
 {'year': 1952, 'month': 'Dec', 'passengers': 194},
 {'year': 1953, 'month': 'Jan', 'passengers': 196},
 {'year': 1953, 'month': 'Feb', 'passengers': 196},
 {'year': 1953, 'month': 'Mar', 'passengers': 236},
 {'year': 1953, 'month': 'Apr', 'passengers': 235},
 {'year': 1953, 'month': 'May', 'passengers': 229},
 {'year': 1953, 'month': 'Jun', 'passengers': 243},
 {'year': 1953, 'month': 'Jul', 'passengers': 264},
 {'year': 1953, 'month': 'Aug', 'passengers': 272},
 {'year': 1953, 'month': 'Sep', 'passengers': 237},
 {'year': 1953, 'month': 'Oct', 'passengers': 211},
 {'year': 1953, 'month': 'Nov', 'passengers': 180},
 {'year': 1953, 'month': 'Dec', 'passengers': 201},
 {'year': 1954, 'month': 'Jan', 'passengers': 204},
 {'year': 1954, 'month': 'Feb', 'passengers': 188},
 {'year': 1954, 'month': 'Mar', 'passengers': 235},
 {'year': 1954, 'month': 'Apr', 'passengers': 227},
 {'year': 1954, 'month': 'May', 'passengers': 234},
 {'year': 1954, 'month': 'Jun', 'passengers': 264},
 {'year': 1954, 'month': 'Jul', 'passengers': 302},
 {'year': 1954, 'month': 'Aug', 'passengers': 293},
 {'year': 1954, 'month': 'Sep', 'passengers': 259},
 {'year': 1954, 'month': 'Oct', 'passengers': 229},
 {'year': 1954, 'month': 'Nov', 'passengers': 203},
 {'year': 1954, 'month': 'Dec', 'passengers': 229},
 {'year': 1955, 'month': 'Jan', 'passengers': 242},
 {'year': 1955, 'month': 'Feb', 'passengers': 233},
 {'year': 1955, 'month': 'Mar', 'passengers': 267},
 {'year': 1955, 'month': 'Apr', 'passengers': 269},
 {'year': 1955, 'month': 'May', 'passengers': 270},
 {'year': 1955, 'month': 'Jun', 'passengers': 315},
 {'year': 1955, 'month': 'Jul', 'passengers': 364},
 {'year': 1955, 'month': 'Aug', 'passengers': 347},
 {'year': 1955, 'month': 'Sep', 'passengers': 312},
 {'year': 1955, 'month': 'Oct', 'passengers': 274},
 {'year': 1955, 'month': 'Nov', 'passengers': 237},
 {'year': 1955, 'month': 'Dec', 'passengers': 278},
 {'year': 1956, 'month': 'Jan', 'passengers': 284},
 {'year': 1956, 'month': 'Feb', 'passengers': 277},
 {'year': 1956, 'month': 'Mar', 'passengers': 317},
 {'year': 1956, 'month': 'Apr', 'passengers': 313},
 {'year': 1956, 'month': 'May', 'passengers': 318},
 {'year': 1956, 'month': 'Jun', 'passengers': 374},
 {'year': 1956, 'month': 'Jul', 'passengers': 413},
 {'year': 1956, 'month': 'Aug', 'passengers': 405},
 {'year': 1956, 'month': 'Sep', 'passengers': 355},
 {'year': 1956, 'month': 'Oct', 'passengers': 306},
 {'year': 1956, 'month': 'Nov', 'passengers': 271},
 {'year': 1956, 'month': 'Dec', 'passengers': 306},
 {'year': 1957, 'month': 'Jan', 'passengers': 315},
 {'year': 1957, 'month': 'Feb', 'passengers': 301},
 {'year': 1957, 'month': 'Mar', 'passengers': 356},
 {'year': 1957, 'month': 'Apr', 'passengers': 348},
 {'year': 1957, 'month': 'May', 'passengers': 355},
 {'year': 1957, 'month': 'Jun', 'passengers': 422},
 {'year': 1957, 'month': 'Jul', 'passengers': 465},
 {'year': 1957, 'month': 'Aug', 'passengers': 467},
 {'year': 1957, 'month': 'Sep', 'passengers': 404},
 {'year': 1957, 'month': 'Oct', 'passengers': 347},
 {'year': 1957, 'month': 'Nov', 'passengers': 305},
 {'year': 1957, 'month': 'Dec', 'passengers': 336},
 {'year': 1958, 'month': 'Jan', 'passengers': 340},
 {'year': 1958, 'month': 'Feb', 'passengers': 318},
 {'year': 1958, 'month': 'Mar', 'passengers': 362},
 {'year': 1958, 'month': 'Apr', 'passengers': 348},
 {'year': 1958, 'month': 'May', 'passengers': 363},
 {'year': 1958, 'month': 'Jun', 'passengers': 435},
 {'year': 1958, 'month': 'Jul', 'passengers': 491},
 {'year': 1958, 'month': 'Aug', 'passengers': 505},
 {'year': 1958, 'month': 'Sep', 'passengers': 404},
 {'year': 1958, 'month': 'Oct', 'passengers': 359},
 {'year': 1958, 'month': 'Nov', 'passengers': 310},
 {'year': 1958, 'month': 'Dec', 'passengers': 337},
 {'year': 1959, 'month': 'Jan', 'passengers': 360},
 {'year': 1959, 'month': 'Feb', 'passengers': 342},
 {'year': 1959, 'month': 'Mar', 'passengers': 406},
 {'year': 1959, 'month': 'Apr', 'passengers': 396},
 {'year': 1959, 'month': 'May', 'passengers': 420},
 {'year': 1959, 'month': 'Jun', 'passengers': 472},
 {'year': 1959, 'month': 'Jul', 'passengers': 548},
 {'year': 1959, 'month': 'Aug', 'passengers': 559},
 {'year': 1959, 'month': 'Sep', 'passengers': 463},
 {'year': 1959, 'month': 'Oct', 'passengers': 407},
 {'year': 1959, 'month': 'Nov', 'passengers': 362},
 {'year': 1959, 'month': 'Dec', 'passengers': 405},
 {'year': 1960, 'month': 'Jan', 'passengers': 417},
 {'year': 1960, 'month': 'Feb', 'passengers': 391},
 {'year': 1960, 'month': 'Mar', 'passengers': 419},
 {'year': 1960, 'month': 'Apr', 'passengers': 461},
 {'year': 1960, 'month': 'May', 'passengers': 472},
 {'year': 1960, 'month': 'Jun', 'passengers': 535},
 {'year': 1960, 'month': 'Jul', 'passengers': 622},
 {'year': 1960, 'month': 'Aug', 'passengers': 606},
 {'year': 1960, 'month': 'Sep', 'passengers': 508},
 {'year': 1960, 'month': 'Oct', 'passengers': 461},
 {'year': 1960, 'month': 'Nov', 'passengers': 390},
 {'year': 1960, 'month': 'Dec', 'passengers': 432}]

df = pd.DataFrame(data)
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.lineplot(x="month", y="passengers", hue='year',
             data=df)
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %% [markdown]
# ### Exercise

# %%
tips_df = sns.load_dataset('tips')
tips_df['score'] = np.log(tips_df['total_bill']+1)
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size     score
# 0       16.99  1.01  Female     No  Sun  Dinner     2  2.889816
# 1       10.34  1.66    Male     No  Sun  Dinner     3  2.428336
# 2       21.01  3.50    Male     No  Sun  Dinner     3  3.091497
# 3       23.68  3.31    Male     No  Sun  Dinner     2  3.205993
# 4       24.59  3.61  Female     No  Sun  Dinner     4  3.242202

# %% [markdown]
# ## Visualizing data distribution

# %% [markdown]
# ### Histogram

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size     score
# 0         16.99  1.01  Female     No   Sun  Dinner     2  2.889816
# 1         10.34  1.66    Male     No   Sun  Dinner     3  2.428336
# 2         21.01  3.50    Male     No   Sun  Dinner     3  3.091497
# 3         23.68  3.31    Male     No   Sun  Dinner     2  3.205993
# 4         24.59  3.61  Female     No   Sun  Dinner     4  3.242202
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  3.402197
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  3.338613
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  3.164208
# 242       17.82  1.75    Male     No   Sat  Dinner     2  2.934920
# 243       18.78  3.00  Female     No  Thur  Dinner     2  2.984671
#
# [244 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.histplot(data=tips_df,x='score')
# Out:
# <Axes: xlabel='score', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.distplot(tips_df['score'], kde=False)
# Out:
# <Axes: xlabel='score'>

# %% [markdown]
# ### KDE Plot

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.distplot(tips_df['score'])
# Out:
# <Axes: xlabel='score', ylabel='Density'>

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.distplot(tips_df['score'], hist=False)
# Out:
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ### Exercise

# %%
iris_df = sns.load_dataset('iris')
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Visualizing  Categorical Data

# %% [markdown]
# ### Box Plot

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size     score
# 0       16.99  1.01  Female     No  Sun  Dinner     2  2.889816
# 1       10.34  1.66    Male     No  Sun  Dinner     3  2.428336
# 2       21.01  3.50    Male     No  Sun  Dinner     3  3.091497
# 3       23.68  3.31    Male     No  Sun  Dinner     2  3.205993
# 4       24.59  3.61  Female     No  Sun  Dinner     4  3.242202

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.boxplot( y=tips_df["total_bill"], color='green' )
# Out:
# <Axes: ylabel='total_bill'>

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips_df, linewidth=2.5, palette="Set3")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Swarm Plot

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size     score
# 0       16.99  1.01  Female     No  Sun  Dinner     2  2.889816
# 1       10.34  1.66    Male     No  Sun  Dinner     3  2.428336
# 2       21.01  3.50    Male     No  Sun  Dinner     3  3.091497
# 3       23.68  3.31    Male     No  Sun  Dinner     2  3.205993
# 4       24.59  3.61  Female     No  Sun  Dinner     4  3.242202

# %%
sns.catplot(x="smoker", y="total_bill", data=tips_df)

# %%
sns.catplot(x="smoker", y="total_bill",hue= 'sex',kind="swarm",data=tips_df)

# %% [markdown]
# ### Bar Plot

# %%
df = pd.DataFrame({'Provinsi':['DKI','Jabar','Jateng','Jatim',
                              'Kaltim','Sumbar','Sulteng','Banten'],
                   'Tingkat Pencemaran Udara' : [99,89,79,69,
                                        59,49,39,29]
                  })
df
# Out:
#   Provinsi  Tingkat Pencemaran Udara
# 0      DKI                        99
# 1    Jabar                        89
# 2   Jateng                        79
# 3    Jatim                        69
# 4   Kaltim                        59
# 5   Sumbar                        49
# 6  Sulteng                        39
# 7   Banten                        29

# %%
fig, ax = plt.subplots(figsize=(15,10))

sns.barplot(x = 'Provinsi',y='Tingkat Pencemaran Udara',data=df,ax=ax,color ='maroon')
# Out:
# <Axes: xlabel='Provinsi', ylabel='Tingkat Pencemaran Udara'>

# %% [markdown]
# ### Exercise

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size     score
# 0       16.99  1.01  Female     No  Sun  Dinner     2  2.889816
# 1       10.34  1.66    Male     No  Sun  Dinner     3  2.428336
# 2       21.01  3.50    Male     No  Sun  Dinner     3  3.091497
# 3       23.68  3.31    Male     No  Sun  Dinner     2  3.205993
# 4       24.59  3.61  Female     No  Sun  Dinner     4  3.242202

# %% [markdown]
# ## Choosing color palettes

# %%
fig, ax = plt.subplots(figsize=(15,10))

sns.barplot(x = 'Provinsi',y='Tingkat Pencemaran Udara',data=df,ax=ax,
               palette=reversed(sns.color_palette("Reds_d", n_colors=8))
               )
# Out:
# <Axes: xlabel='Provinsi', ylabel='Tingkat Pencemaran Udara'>
